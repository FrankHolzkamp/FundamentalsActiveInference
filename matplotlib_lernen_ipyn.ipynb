# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankHolzkamp/FundamentalsActiveInference/blob/main/matplotlib_lernen_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

# %%
np.random.randint(0,3,4)
# Out:
# array([2, 1, 2, 0])

# %%
# fig, ax = plt.subplots()  # Create a figure containing a single axes.
fig = plt.figure(figsize=(4, 4), facecolor='lightskyblue',
                 layout='constrained')
fig.suptitle('Figure')
ax = fig.add_subplot()
ax.set_title('Axes', loc='left', fontstyle='oblique', fontsize='medium')

ax.plot(np.random.randint(0,4,4), np.random.randint(0,4,4))  # Plot some data on the axes.

# %%
# fig = plt.figure()  # an empty figure with no Axes
# plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# print(axs)
for i in range(2):
  for j in range(2):
    axs[i, j].plot(np.random.randint(0,4,4), np.random.randint(0,4,4))
# a figure with one axes on the left, and two on the right:
# fig, axs = plt.subplot_mosaic([['left', 'right_top'],
#                               ['left', 'right_bottom']])

# %%
for i in range(2):
    print(i, end=", ") # prints: 0, 1, 2, 3, 4,
# Out:
# 0, 1,
