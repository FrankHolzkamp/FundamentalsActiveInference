# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankHolzkamp/FundamentalsActiveInference/blob/main/Probability_Models_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

rng = np.random.default_rng(42)

# %%
print(rng.random())
print(rng.random(5))
print(rng.random([3,3]))
# Out:
# 0.7739560485559633
# [0.43887844 0.85859792 0.69736803 0.09417735 0.97562235]
# [[0.7611397  0.78606431 0.12811363]
#  [0.45038594 0.37079802 0.92676499]
#  [0.64386512 0.82276161 0.4434142 ]]

# %%
# Generate a Binomial(50,0.2) random variable
def binomial(n,p):
  U=rng.random(n)
  return sum(U < p)

print(binomial(50,0.9))
# Out:
# 48

# %%
# random choice from array
def X ():
  A = [0.35 ,0.5 ,0.9 ,1]
  x = [1 ,2 ,3 ,4]
  j = 0
  U = rng . random ()
  while U > A [ j ]:
    j = j + 1
    return x [ j ]

# %%
# print(X())
# identisch mit
print(rng.choice([1,2,3,4],p=[0.35,0.15,0.4,0.1]))
# Out:
# 3

# %%
def bernoulli(p):
    U = rng.random()
    return(U < p)

# %%
n = 10000
U = rng.random(n)
toss = (U < 0.6)
# print(toss)
avg = [sum(toss[:i])/i for i in range(1,n+1)]
# print(avg)

plt . xlabel ( " Coin Toss Number " )
plt . ylabel ( " Pr op or tio n of Heads " )
plt . axis ([0 , n ,0 ,1])
plt . plot ( range (1 , n +1) , avg )
plt . show ()

# %%
n = 100
erg = rng.normal

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters for the normal distribution
mu = 7  # Mean
sigma = 0.5 # Standard deviation

# Create a range of x values
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)

# Calculate the PDF using the NumPy formula
pdf_values_numpy = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2)
cdf_values_numpy = [sum(pdf_values[:i]) for i in range(len(pdf_values))]
# Plot the PDF
plt.figure(figsize=(8, 5))
plt.plot(x, pdf_values_numpy, label=f'Normal Distribution (μ={mu}, σ={sigma}) - NumPy')
plt.plot(x, cdf_values_numpy, label=f'CDF ')
plt.title('Probability Density Function (PDF) of a Normal Distribution (NumPy)')
plt.xlabel('X-Value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.show()
